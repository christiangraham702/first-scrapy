# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_json('data/all_num69.json')

# %%
# final_df = main_df.drop_duplicates(subset=['S', 'P'])
f_df = df.drop_duplicates(subset=['pid'])
f_df
# Out:
#              pid                                               link  \
# 0     7538573396  https://ksu.craigslist.org/search/sss?query=ba...
# 1     7539276265  https://pensacola.craigslist.org/search/sss?qu...
# 3     7538471164  https://ksu.craigslist.org/search/sss?query=ba...
# 4     7536406787  https://ksu.craigslist.org/search/sss?query=ba...
# 5     7536205561  https://ksu.craigslist.org/search/sss?query=ba...
# ...          ...                                                ...
# 6634  7536407217  https://monterey.craigslist.org/search/sss?que...
# 6640  7527668166  https://susanville.craigslist.org/search/sss?q...
# 6642  7529626936  https://humboldt.craigslist.org/search/sss?que...
# 6643  7529623101  https://humboldt.craigslist.org/search/sss?que...
# 6675  7520460471  https://susanville.craigslist.org/search/sss?q...
#
#                                                   title                date  \
# 0               2 BIG cans similac advance baby formula 2022-09-28 13:27:00
# 1                                  Simalac Baby Formula 2022-09-28 09:32:00
# 3          free baby food and formula, slighly expired. 2022-09-26 09:20:00
# 4                                          Baby formula 2022-09-20 21:18:00
# 5     UNUSED Baby Formula - Elecare Jr. Unflavored T... 2022-09-20 12:57:00
# ...                                                 ...                 ...
# 6634                                Enfamil Coupon Book 2022-09-20 19:20:00
# 6640                           Earths Best Baby formula 2022-08-29 19:58:00
# 6642                                   Puramino formula 2022-09-03 16:53:00
# 6643                             Enfamil infant formula 2022-09-03 16:40:00
# 6675  Nestle NAN 1 Pro Non-GMO Powder Infant Formula... 2022-09-08 09:05:00
#
#       region            price
# 0        NaN              $30
# 1        NaN             $140
# 3        NaN  no price posted
# 4        NaN              $12
# 5        NaN              $38
# ...      ...              ...
# 6634     NaN              $45
# 6640     NaN              $30
# 6642     NaN              $35
# 6643     NaN              $12
# 6675     NaN              $12
#
# [1686 rows x 6 columns]

# %%
data = np.array(list(df['pid']))
data_float = data.astype(np.float64)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/3r/38nfxvd92ng3g3f3h9phbx440000gn/T/ipykernel_62686/3480917097.py in <module>
#       1 data = np.array(list(df['pid']))
# ----> 2 data_float = data.astype(np.float64)
#
# ValueError: could not convert string to float: ' [no listings here]'
